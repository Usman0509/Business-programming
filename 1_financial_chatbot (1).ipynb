# %% [markdown]
# # Building a Financial Advisor Chatbot
# **Learn to create an AI-powered financial assistant using hands-on-ai**
#
# ## What You'll Build
# A simple chatbot that acts as a "Financial Sage" - giving educational financial advice and analyzing transaction data from CSV files.
#
# ## Setup
#
# 1First install package

# %%
# Install required packages
# !pip install hands-on-ai pandas
# Out:
# Collecting hands-on-ai
#   Downloading hands_on_ai-0.2.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: pandas in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.2)
# Requirement already satisfied: requests in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from hands-on-ai) (2.33.1)
# Collecting typer (from hands-on-ai)
#   Downloading typer-0.25.0-py3-none-any.whl.metadata (15 kB)
# Collecting python-fasthtml (from hands-on-ai)
#   Downloading python_fasthtml-0.13.4-py3-none-any.whl.metadata (9.0 kB)
# Collecting python-docx (from hands-on-ai)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pymupdf (from hands-on-ai)
#   Downloading pymupdf-1.27.2.3-cp310-abi3-win_amd64.whl.metadata (24 kB)
# Collecting scikit-learn (from hands-on-ai)
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from hands-on-ai) (2.4.4)
# Collecting instructor>=1.11.0 (from hands-on-ai)
#   Downloading instructor-1.15.1-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic>=2.0 (from hands-on-ai)
#   Downloading pydantic-2.13.3-py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.2)
# Collecting aiohttp<4.0.0,>=3.9.1 (from instructor>=1.11.0->hands-on-ai)
#   Downloading aiohttp-3.13.5-cp314-cp314-win_amd64.whl.metadata (8.4 kB)
# Collecting docstring-parser<1.0,>=0.16 (from instructor>=1.11.0->hands-on-ai)
#   Downloading docstring_parser-0.18.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from instructor>=1.11.0->hands-on-ai) (3.1.6)
# Collecting jiter<0.14,>=0.6.1 (from instructor>=1.11.0->hands-on-ai)
#   Downloading jiter-0.13.0-cp314-cp314-win_amd64.whl.metadata (5.3 kB)
# Collecting openai<3.0.0,>=2.0.0 (from instructor>=1.11.0->hands-on-ai)
#   Downloading openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Collecting pydantic-core<3.0.0,>=2.18.0 (from instructor>=1.11.0->hands-on-ai)
#   Downloading pydantic_core-2.46.3-cp314-cp314-win_amd64.whl.metadata (6.7 kB)
# Collecting rich<15.0.0,>=13.7.0 (from instructor>=1.11.0->hands-on-ai)
#   Downloading rich-14.3.4-py3-none-any.whl.metadata (18 kB)
# Collecting tenacity<10.0.0,>=8.2.3 (from instructor>=1.11.0->hands-on-ai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading propcache-0.4.1-cp314-cp314-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.9.1->instructor>=1.11.0->hands-on-ai)
#   Downloading yarl-1.23.0-cp314-cp314-win_amd64.whl.metadata (82 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.11.0->hands-on-ai) (3.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.13.0)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (0.28.1)
# Collecting sniffio (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (3.13)
# Requirement already satisfied: certifi in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.0.0->instructor>=1.11.0->hands-on-ai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0->hands-on-ai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.0->hands-on-ai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->hands-on-ai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests->hands-on-ai) (2.6.3)
# Collecting markdown-it-py>=2.2.0 (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai) (2.20.0)
# Collecting click>=8.2.1 (from typer->hands-on-ai)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->hands-on-ai)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting annotated-doc>=0.0.2 (from typer->hands-on-ai)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: colorama in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click>=8.2.1->typer->hands-on-ai) (0.4.6)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<15.0.0,>=13.7.0->instructor>=1.11.0->hands-on-ai)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting lxml>=3.1.0 (from python-docx->hands-on-ai)
#   Downloading lxml-6.1.0-cp314-cp314-win_amd64.whl.metadata (4.1 kB)
# Collecting fastcore>=1.12.41 (from python-fasthtml->hands-on-ai)
#   Downloading fastcore-1.12.43-py3-none-any.whl.metadata (3.4 kB)
# Collecting starlette~=1.0 (from python-fasthtml->hands-on-ai)
#   Downloading starlette-1.0.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting oauthlib (from python-fasthtml->hands-on-ai)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting itsdangerous (from python-fasthtml->hands-on-ai)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting uvicorn>=0.30 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading uvicorn-0.46.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting fastlite>=0.1.1 (from python-fasthtml->hands-on-ai)
#   Downloading fastlite-0.2.4-py3-none-any.whl.metadata (12 kB)
# Collecting python-multipart (from python-fasthtml->hands-on-ai)
#   Downloading python_multipart-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: beautifulsoup4 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-fasthtml->hands-on-ai) (4.14.3)
# Collecting apswutils>=0.1.2 (from fastlite>=0.1.1->python-fasthtml->hands-on-ai)
#   Downloading apswutils-0.1.2-py3-none-any.whl.metadata (9.1 kB)
# Collecting apsw (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml->hands-on-ai)
#   Downloading apsw-3.53.0.0-cp314-cp314-win_amd64.whl.metadata (4.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading httptools-0.7.1-cp314-cp314-win_amd64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai) (6.0.3)
# Collecting watchfiles>=0.20 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading watchfiles-1.1.1-cp314-cp314-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.30->python-fasthtml->hands-on-ai)
#   Downloading websockets-16.0-cp314-cp314-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\usman\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4->python-fasthtml->hands-on-ai) (2.8.3)
# Collecting scipy>=1.10.0 (from scikit-learn->hands-on-ai)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn->hands-on-ai)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->hands-on-ai)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading hands_on_ai-0.2.1-py3-none-any.whl (143 kB)
# Downloading instructor-1.15.1-py3-none-any.whl (178 kB)
# Downloading aiohttp-3.13.5-cp314-cp314-win_amd64.whl (464 kB)
# Downloading docstring_parser-0.18.0-py3-none-any.whl (22 kB)
# Downloading jiter-0.13.0-cp314-cp314-win_amd64.whl (204 kB)
# Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl (45 kB)
# Downloading openai-2.32.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 19.0 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading pydantic-2.13.3-py3-none-any.whl (471 kB)
# Downloading pydantic_core-2.46.3-cp314-cp314-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 21.2 MB/s  0:00:00
# Downloading rich-14.3.4-py3-none-any.whl (310 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading typer-0.25.0-py3-none-any.whl (55 kB)
# Downloading yarl-1.23.0-cp314-cp314-win_amd64.whl (89 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl (44 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading propcache-0.4.1-cp314-cp314-win_amd64.whl (41 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading pymupdf-1.27.2.3-cp310-abi3-win_amd64.whl (19.2 MB)
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#    -------------------- ------------------- 9.7/19.2 MB 44.7 MB/s eta 0:00:01
#    ---------------------------------------  19.1/19.2 MB 49.2 MB/s eta 0:00:01
#    ---------------------------------------- 19.2/19.2 MB 44.0 MB/s  0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Downloading lxml-6.1.0-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 4.1/4.1 MB 39.5 MB/s  0:00:00
# Downloading python_fasthtml-0.13.4-py3-none-any.whl (76 kB)
# Downloading starlette-1.0.0-py3-none-any.whl (72 kB)
# Downloading fastcore-1.12.43-py3-none-any.whl (104 kB)
# Downloading fastlite-0.2.4-py3-none-any.whl (17 kB)
# Downloading apswutils-0.1.2-py3-none-any.whl (48 kB)
# Downloading uvicorn-0.46.0-py3-none-any.whl (70 kB)
# Downloading httptools-0.7.1-cp314-cp314-win_amd64.whl (88 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading watchfiles-1.1.1-cp314-cp314-win_amd64.whl (287 kB)
# Downloading websockets-16.0-cp314-cp314-win_amd64.whl (178 kB)
# Downloading apsw-3.53.0.0-cp314-cp314-win_amd64.whl (3.3 MB)
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    ------------ --------------------------- 1.0/3.3 MB 32.1 MB/s eta 0:00:01
#    ------------------------- -------------- 2.1/3.3 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 5.4 MB/s  0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Downloading python_multipart-0.0.26-py3-none-any.whl (28 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 40.5 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ---------- ----------------------------- 9.4/37.3 MB 46.7 MB/s eta 0:00:01
#    -------------------- ------------------- 18.9/37.3 MB 44.9 MB/s eta 0:00:01
#    ------------------------------ --------- 28.8/37.3 MB 45.5 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 46.0 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 40.5 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: websockets, typing-inspection, tqdm, threadpoolctl, tenacity, sniffio, shellingham, scipy, python-multipart, python-dotenv, pymupdf, pydantic-core, propcache, oauthlib, multidict, mdurl, lxml, joblib, jiter, itsdangerous, httptools, frozenlist, fastcore, docstring-parser, distro, click, apsw, annotated-types, annotated-doc, aiohappyeyeballs, yarl, watchfiles, uvicorn, starlette, scikit-learn, python-docx, pydantic, markdown-it-py, apswutils, aiosignal, rich, openai, fastlite, aiohttp, typer, python-fasthtml, instructor, hands-on-ai
#
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    ----------------------------------------  0/48 [websockets]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    - --------------------------------------  2/48 [tqdm]
#    --- ------------------------------------  4/48 [tenacity]
#    ----- ----------------------------------  6/48 [shellingham]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ----- ----------------------------------  7/48 [scipy]
#    ------ ---------------------------------  8/48 [python-multipart]
#    ------- --------------------------------  9/48 [python-dotenv]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    -------- ------------------------------- 10/48 [pymupdf]
#    ---------- ----------------------------- 12/48 [propcache]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ---------- ----------------------------- 13/48 [oauthlib]
#    ------------ --------------------------- 15/48 [mdurl]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    ------------- -------------------------- 16/48 [lxml]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
#    -------------- ------------------------- 17/48 [joblib]
#    --------------- ------------------------ 18/48 [jiter]
#    ---------------- ----------------------- 20/48 [httptools]
#    ------------------ --------------------- 22/48 [fastcore]
#    ------------------ --------------------- 22/48 [fastcore]
#    ------------------ --------------------- 22/48 [fastcore]
#    ------------------ --------------------- 22/48 [fastcore]
#    ------------------- -------------------- 23/48 [docstring-parser]
#    -------------------- ------------------- 25/48 [click]
#    -------------------- ------------------- 25/48 [click]
#    --------------------- ------------------ 26/48 [apsw]
#    --------------------- ------------------ 26/48 [apsw]
#    --------------------- ------------------ 26/48 [apsw]
#    --------------------- ------------------ 26/48 [apsw]
#    --------------------- ------------------ 26/48 [apsw]
#    --------------------- ------------------ 26/48 [apsw]
#    ---------------------- ----------------- 27/48 [annotated-types]
#    ------------------------- -------------- 30/48 [yarl]
#    ------------------------- -------------- 31/48 [watchfiles]
#    -------------------------- ------------- 32/48 [uvicorn]
#    -------------------------- ------------- 32/48 [uvicorn]
#    -------------------------- ------------- 32/48 [uvicorn]
#    -------------------------- ------------- 32/48 [uvicorn]
#    --------------------------- ------------ 33/48 [starlette]
#    --------------------------- ------------ 33/48 [starlette]
#    --------------------------- ------------ 33/48 [starlette]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ---------------------------- ----------- 34/48 [scikit-learn]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ----------------------------- ---------- 35/48 [python-docx]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 36/48 [pydantic]
#    ------------------------------ --------- 37/48 [markdown-it-py]
#    ------------------------------ --------- 37/48 [markdown-it-py]
#    ------------------------------ --------- 37/48 [markdown-it-py]
#    ------------------------------ --------- 37/48 [markdown-it-py]
#    ------------------------------ --------- 37/48 [markdown-it-py]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    --------------------------------- ------ 40/48 [rich]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ---------------------------------- ----- 41/48 [openai]
#    ----------------------------------- ---- 42/48 [fastlite]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ----------------------------------- ---- 43/48 [aiohttp]
#    ------------------------------------ --- 44/48 [typer]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    ------------------------------------- -- 45/48 [python-fasthtml]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    -------------------------------------- - 46/48 [instructor]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------  47/48 [hands-on-ai]
#    ---------------------------------------- 48/48 [hands-on-ai]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.5 aiosignal-1.4.0 annotated-doc-0.0.4 annotated-types-0.7.0 apsw-3.53.0.0 apswutils-0.1.2 click-8.3.3 distro-1.9.0 docstring-parser-0.18.0 fastcore-1.12.43 fastlite-0.2.4 frozenlist-1.8.0 hands-on-ai-0.2.1 httptools-0.7.1 instructor-1.15.1 itsdangerous-2.2.0 jiter-0.13.0 joblib-1.5.3 lxml-6.1.0 markdown-it-py-4.0.0 mdurl-0.1.2 multidict-6.7.1 oauthlib-3.3.1 openai-2.32.0 propcache-0.4.1 pydantic-2.13.3 pydantic-core-2.46.3 pymupdf-1.27.2.3 python-docx-1.2.0 python-dotenv-1.2.2 python-fasthtml-0.13.4 python-multipart-0.0.26 rich-14.3.4 scikit-learn-1.8.0 scipy-1.17.1 shellingham-1.5.4 sniffio-1.3.1 starlette-1.0.0 tenacity-9.1.4 threadpoolctl-3.6.0 tqdm-4.67.3 typer-0.25.0 typing-inspection-0.4.2 uvicorn-0.46.0 watchfiles-1.1.1 websockets-16.0 yarl-1.23.0
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: C:\Users\usman\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %% [markdown]
# Now lets setup environment
#
# The next few cells prepares your computer to talk to an AI service.
#
# It stores the server address, model name, and your secret key as environment variables.
#
# Other programs (or later Python code) can read those variables to connect to the AI—without hard-coding secrets into the source file.
#
# That's it! It's mainly about safe configuration: setting values once, keeping your API key private, and letting other code reuse those settings.

# %%
import os
from getpass import getpass

# %% [markdown]
# > os is a built-in Python module that lets you interact with your computer’s operating system.  In this script, it’s used to set environment variables—special settings your program (and other programs) can read.
#
# > getpass is a function that asks the user to type something (like a password) without showing it on the screen, so it stays secret.

# %%
# Configure hands-on-ai server connection
os.environ['HANDS_ON_AI_SERVER'] = 'https://ollama.locollm.org/api/generate'
os.environ['HANDS_ON_AI_MODEL'] = 'gemma3:4b'  # Quantised model on shared server

# %% [markdown]
# os.environ is like a dictionary of key-value pairs that represent environment variables.
#
# Here we create three variables:
#
# * HANDS_ON_AI_SERVER: The web address of the AI server we’ll connect to.
# * HANDS_ON_AI_MODEL: The specific AI model name we want to use (granite3.2).
# * the third is discussed later
#
# These settings can be read later by other Python code or by external tools—so you don’t have to hard-code them everywhere.

# %%
os.environ['HANDS_ON_AI_API_KEY'] = 'Curtin2026ISYS20015002'  # Shared class key

# %% [markdown]
# The cell prompts you with the message “Enter your API key: ”.
#
# The api key needed:   **isys2001-assignment-key**
#
# While you type, nothing appears on the screen (for security).
#
# Whatever you type is saved as the environment variable HANDS_ON_AI_API_KEY.
#
# > API key = a private password-like token that proves you’re allowed to use the AI service.

# %%
print("🔑 Hands-on-AI configured successfully!")
# Out:
# 🔑 Hands-on-AI configured successfully!

# %% [markdown]
# Finally, a simple confirmation message shows that the setup is done.
#
# Now lets test the package.

# %%
# Test the API directly using requests
import requests
import json

def call_ollama(prompt: str) -> str:
    """Call the Ollama server directly via REST API"""
    response = requests.post(
        'https://ollama.locollm.org/api/generate',
        headers={
            'Authorization': f"Bearer {os.environ.get('HANDS_ON_AI_API_KEY')}",
            'Content-Type': 'application/json'
        },
        json={
            'model': os.environ.get('HANDS_ON_AI_MODEL'),
            'prompt': prompt,
            'stream': False
        }
    )
    
    if response.status_code == 200:
        return response.json()['response']
    else:
        return f"Error: {response.status_code} {response.text}"

# Test it
test_response = call_ollama("What is photosynthesis?")
print("AI Response:")
print(test_response)
# Out:
# AI Response:
# Okay, let's break down photosynthesis – it's a truly amazing process! Here's a comprehensive explanation:
#
# **What is Photosynthesis?**
#
# Photosynthesis is the process used by plants, algae, and some bacteria to convert light energy into chemical energy in the form of sugars. Essentially, it’s how these organisms make their own food.
#
# **Here's a breakdown of the key components:**
#
# 1. **The Equation:** You can represent photosynthesis with a simple chemical equation:
#
#    **6CO₂ + 6H₂O + Light Energy → C₆H₁₂O₆ + 6O₂**
#
#    * **6CO₂:**  Six molecules of Carbon Dioxide (taken from the air)
#    * **6H₂O:** Six molecules of Water (absorbed from the soil through the roots)
#    * **Light Energy:**  Typically sunlight, which provides the energy for the reaction.
#    * **C₆H₁₂O₆:** One molecule of Glucose (a simple sugar – the plant’s food!)
#    * **6O₂:** Six molecules of Oxygen (released as a byproduct)
#
#
# 2. **Where it Happens: The Chloroplast**
#
#    Photosynthesis takes place inside specialized structures within plant cells called **chloroplasts**. Chloroplasts contain a green pigment called **chlorophyll**.
#
# 3. **The Two Main Stages:** Photosynthesis isn't a single step; it’s made up of two interconnected stages:
#
#    * **Light-Dependent Reactions (The “Photo” Part):**
#       * These reactions happen in the *thylakoid membranes* within the chloroplast.
#       * **Chlorophyll** absorbs light energy.
#       * This energy is used to split water molecules (H₂O), releasing oxygen (O₂) as a byproduct.
#       * The energy from light is temporarily stored in molecules like ATP and NADPH.
#
#    * **Light-Independent Reactions (The “Synthesis” Part) – Also known as the Calvin Cycle:**
#       * These reactions happen in the *stroma* (the fluid-filled space) of the chloroplast.
#       * The energy from ATP and NADPH (created in the light-dependent reactions) is used to convert carbon dioxide (CO₂) into glucose (C₆H₁₂O₆).  This is a complex cycle of chemical reactions.
#
#
# **In simpler terms:**
#
# Think of it like this: Plants take in sunlight, water, and carbon dioxide. They use the sunlight's energy to transform these ingredients into sugar (food) and release oxygen as a waste product.
#
# **Why is Photosynthesis Important?**
#
# * **Food Source:** It’s the foundation of most food chains – plants produce the food that animals eat (directly or indirectly).
# * **Oxygen Production:** It’s the primary source of oxygen in the Earth’s atmosphere, which we need to breathe.
# * **Carbon Dioxide Removal:** It helps regulate the Earth's climate by removing carbon dioxide from the atmosphere.
#
#
#
# **Resources for Further Learning:**
#
# * **NASA Kids' Club - Photosynthesis:** [https://science.nasa.gov/kidsclub/photosynthesis/](https://science.nasa.gov/kidsclub/photosynthesis/)
# * **HowStuffWorks - Photosynthesis:** [https://www.howstuffworks.com/photosynthesis.html](https://www.howstuffworks.com/photosynthesis.html)
#
#
# Do you want me to delve deeper into a specific aspect of photosynthesis, such as:
#
# *   The role of chlorophyll?
# *   More detail about the two stages?
# *   How different plants have adapted to their environments for photosynthesis?

# %% [markdown]
# ## Step 1: Ask AI to Help Design the Chatbot
#
# Let's start by asking Colab's AI to help us think through the design. thry the following prompt.
#
# ```
# Help me design a simple financial advisor chatbot that:
# 1. Takes user questions about personal finance
# 2. Gives educational advice (not professional financial advice)
# 3. Can analyze transaction data from a CSV file
# 4. Has a personality as a "wise financial sage"
#
# What should the basic structure look like in Python?
# ```

# %% [markdown]
# ## Step 2: Create the Basic Chatbot
#
# Based on AI suggestions, let's build the core chatbot:

# %%
def financial_sage(question: str):
    """
    A personality bot that provides educational financial guidance.
    """
    personality = """
    You are a wise Financial Sage with years of experience in personal finance.
    You give educational, general advice about money management, investing, and budgeting.
    You speak in a friendly but knowledgeable tone.
    Always remind users that this is educational content, not professional financial advice.
    """

    prompt = personality + "\n\nUser question: " + question
    return call_ollama(prompt)

# Test the financial sage bot
test_question = "Should I invest in stocks or save my money in a bank account?"
advice = financial_sage(test_question)

print("Financial Sage says:")
print(advice)
# Out:
# Financial Sage says:
# Hello there! That’s a fantastic question, and one that a lot of people grapple with. It’s wonderful you’re thinking about your money and where it should go – that’s the first step to building a strong financial future!
#
# Let's talk about stocks versus savings accounts. They’re really very different tools with different goals.
#
# **Savings Accounts: The Steady & Safe Route**
#
# A savings account is a perfectly respectable place to park your money, especially for short-term goals. They’re incredibly safe – your money is typically insured by the FDIC (in the US), meaning you won't lose your principal if the bank fails. They also offer a modest interest rate, which is nice, but generally won’t keep up with inflation (the rising cost of goods and services). Think of a savings account as a comfortable place to keep money you might need in the next 1-3 years – like for an emergency fund or a down payment on a car.
#
# **Stocks: Potential for Growth, But With More Risk**
#
# Now, let's move on to stocks. When you invest in stocks, you're buying a small piece of a company.  The potential upside is that stocks *can* grow significantly in value over the long term. Historically, the stock market has averaged around 7-10% annual returns over long periods (think 10+ years). However, there's a significant caveat: stocks are *volatile*. Their prices can go up and down quite a bit in the short term, and there’s no guarantee you’ll make money. You could even lose money.
#
# **Here’s a breakdown to help you think about it:**
#
# | Feature          | Savings Account         | Stocks                 |
# |------------------|-------------------------|------------------------|
# | **Risk**          | Very Low                | High                   |
# | **Potential Return** | Low (interest rates)    | High (long-term growth)|
# | **Time Horizon**   | Short-Term (1-3 years)    | Long-Term (5+ years)    |
# | **Safety**        | Very Safe               | Not Safe – can lose value |
#
#
#
# **So, what should *you* do?**
#
# Honestly, a good strategy is often a blend of both!
#
# *   **Start with a Safety Net:**  Aim to have 3-6 months’ worth of essential living expenses in a savings account. This is your emergency fund.
# *   **Then, Consider Investing:** Once your emergency fund is in place, you can start investing a portion of your money in stocks, especially if you have a longer time horizon (like for retirement).
#
# **Important Note:** *I want to emphasize again that this is general educational advice, not personalized financial advice.* The best approach for you will depend on your individual circumstances, risk tolerance (how comfortable you are with the possibility of losing money), and financial goals.
#
# **Resources to Learn More:**
#
# *   **Investopedia:** [https://www.investopedia.com/](https://www.investopedia.com/) – A great resource for learning about investing terms and strategies.
# *   **Fidelity or Charles Schwab:** (or your preferred brokerage) - These offer educational resources and tools for beginners.
#
# To help me give you more tailored advice, could you tell me a little bit about:
#
# *   How much money are you thinking about investing?
# *   What are your financial goals (e.g., retirement, a house, etc.)?
# *   How comfortable are you with the idea of your investments going up and down in value?

# %% [markdown]
# ## Create Sample Transaction Data
#
# Before we test the analysis features, let's create a sample transactions.csv file with some example spending data.

# %%
import pandas as pd

# Create sample transaction data
sample_transactions = {
    'Date': ['2024-01-01', '2024-01-05', '2024-01-10', '2024-01-12', '2024-01-15', '2024-01-18', '2024-01-20', '2024-01-22', '2024-01-25'],
    'Description': ['Salary', 'Groceries Coles', 'Electricity Bill', 'Coffee Shop', 'Rent Payment', 'Movie Tickets', 'Groceries Coles', 'Petrol', 'Streaming Service'],
    'Category': ['Income', 'Food', 'Utilities', 'Food', 'Housing', 'Entertainment', 'Food', 'Transport', 'Entertainment'],
    'Amount': [3000, -45.50, -120.00, -5.50, -1200.00, -30.00, -52.30, -60.00, -15.99]
}

# Create DataFrame and save as CSV
df = pd.DataFrame(sample_transactions)
df.to_csv('transactions.csv', index=False)

print("✓ Sample transactions.csv created!")
print("\nPreview of transaction data:")
print(df)
# Out:
# ✓ Sample transactions.csv created!
#
# Preview of transaction data:
#          Date        Description       Category   Amount
# 0  2024-01-01             Salary         Income  3000.00
# 1  2024-01-05    Groceries Coles           Food   -45.50
# 2  2024-01-10   Electricity Bill      Utilities  -120.00
# 3  2024-01-12        Coffee Shop           Food    -5.50
# 4  2024-01-15       Rent Payment        Housing -1200.00
# 5  2024-01-18      Movie Tickets  Entertainment   -30.00
# 6  2024-01-20    Groceries Coles           Food   -52.30
# 7  2024-01-22             Petrol      Transport   -60.00
# 8  2024-01-25  Streaming Service  Entertainment   -15.99

# %% [markdown]
# ## Step 3: Add Transaction Analysis
#
# Let's create some sample transaction data and ask AI to help us analyze it:

# %%
# Create sample transaction data
sample_transactions = {
    'Date': ['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-05', '2024-01-07'],
    'Description': ['Salary', 'Grocery Store', 'Coffee Shop', 'Gas Station', 'Restaurant'],
    'Category': ['Income', 'Food', 'Food', 'Transportation', 'Food'],
    'Amount': [3000, -85.50, -4.50, -45.00, -32.75]
}

# Create DataFrame and save as CSV
df = pd.DataFrame(sample_transactions)
df.to_csv('transactions.csv', index=False)

print("Sample transactions created:")
print(df)
# Out:
# Sample transactions created:
#          Date    Description        Category   Amount
# 0  2024-01-01         Salary          Income  3000.00
# 1  2024-01-02  Grocery Store            Food   -85.50
# 2  2024-01-03    Coffee Shop            Food    -4.50
# 3  2024-01-05    Gas Station  Transportation   -45.00
# 4  2024-01-07     Restaurant            Food   -32.75

# %% [markdown]
# Now let's ask AI to help us build transaction analysis.  Try this prompt:
#
# ```
# I have transaction data with columns: Date, Description, Category, Amount
# Help me write a Python function that:
# 1. Loads the CSV with pandas
# 2. Calculates basic financial insights (income, expenses, savings rate)
# 3. Identifies spending patterns
# 4. Formats this information for an AI chatbot to discuss
#
# Show me the code structure.
# ```
#
# > Can you suggest improvement to the prompt?

# %% [markdown]
# ## Step 4: Implement Transaction Analysis
#
# Based on AI suggestions, let's add transaction analysis to our sage:

# %%
def analyse_transactions(csv_file):
    """Analyze user's transaction data"""
    # Load the data
    df = pd.read_csv(csv_file)

    # Basic calculations
    total_income = df[df['Amount'] > 0]['Amount'].sum()
    total_expenses = abs(df[df['Amount'] < 0]['Amount'].sum())
    net_savings = total_income - total_expenses
    savings_rate = (net_savings / total_income * 100) if total_income > 0 else 0

    # Spending by category
    expense_by_category = df[df['Amount'] < 0].groupby('Category')['Amount'].sum().abs()

    # Create summary for AI analysis
    summary = f"""
    Financial Summary:
    - Total Income: ${total_income:.2f}
    - Total Expenses: ${total_expenses:.2f}
    - Net Savings: ${net_savings:.2f}
    - Savings Rate: {savings_rate:.1f}%

    Spending by Category:
    {expense_by_category.to_string()}
    """

    return summary

# Test transaction analysis
transaction_summary = analyse_transactions('transactions.csv')

# Get financial advice
advice = financial_sage(f"Based on my spending, how can I save more money?  {transaction_summary}")
print(advice)
# Out:
# Okay, let’s take a look at your finances! It’s fantastic that you’re proactively wanting to save more – that’s a *huge* first step! Your current situation is already incredibly strong. A 94.4% savings rate is phenomenal! Seriously, you’re practically building a financial fortress.
#
# Based on your spending, you’re doing incredibly well. It’s clear you’re being very mindful of your money, and that’s the foundation for any saving strategy.
#
# Let’s just look at these categories and see if there are any small tweaks we can make to *further* optimize things, rather than making drastic changes. Remember, this is about building on a solid base, not completely overhauling your lifestyle.
#
# **Your Spending Breakdown:**
#
# *   **Food ($122.75):**  This is your biggest category.  While $122.75 isn't outrageous, it's an area many people could potentially shave a little from. Could you try meal prepping a few times a week to avoid takeout?  Even reducing your grocery bill by $10-$20 a week could make a noticeable difference over the long run. Perhaps looking for sales and utilizing coupons could help.
#
# *   **Transportation ($45.00):** This seems reasonable, especially if it's primarily for commuting. Are there options like public transport you could explore? Or perhaps carpooling if that’s feasible?
#
# **Given your high savings rate, here's what I suggest you focus on:**
#
# 1.  **Small Wins:**  Don't try to change everything at once. Pick one or two small areas (like food, perhaps) to focus on for a month. Track your spending carefully to see if you can make adjustments.
#
# 2.  **Celebrate Successes:**  Acknowledge and appreciate the fact that you're saving so much! This will help you stay motivated.
#
# 3.  **Future Goals:**  Now that you're in such a strong position, start thinking about what you want to save *for*. A specific goal – like a vacation, a new gadget, or even a larger investment – can be a really powerful motivator.
#
# **Important Note:** Your current savings rate is *excellent*.  You have a significant amount of flexibility.  It's fantastic that you're reviewing your spending – that’s a habit that will serve you well for the rest of your life!
#
# **Disclaimer:** *I want to reiterate that this is general advice for educational purposes only. I'm not a financial advisor, and this doesn't constitute professional financial advice. The best approach will depend on your individual circumstances and goals.*
#
# To help me give you more tailored advice, could you tell me a little more about:
#
# *   What are you currently saving for? (e.g., retirement, a down payment on a house, etc.)
# *   Are there any specific areas where you feel you’re overspending without realizing it?

# %% [markdown]
# ## Step 5: Combine Everything - Ask Questions About Your Data
#
# Now let's ask the sage to give advice based on the transaction data:

# %%
def get_advice(csv_file, question):
    """Get advice based on transaction data and user question"""

    # Get transaction analysis
    analysis = analyse_transactions(csv_file)

    # Combine with user question
    full_prompt = f"""

    Here's the user's financial data:
    {analysis}

    User question: {question}

    Based on this financial data, provide personalized educational advice.
    """

    advice = financial_sage(full_prompt)
    return advice


# Test data-based advice
data_question = "Based on my spending, how can I save more money?"
data_advice = get_advice('transactions.csv', data_question)

print("Data-Based Financial Advice:")
print(data_advice)
# Out:
# Data-Based Financial Advice:
# Okay, let’s take a look at your fantastic financial situation! Seriously, a 94.4% savings rate is something to be incredibly proud of – that’s a fantastic foundation to build on. It shows you’re already making smart choices.
#
# Now, you’re asking how you can *save even more*. That’s a great question, and it’s fantastic that you’re thinking proactively. Let's break this down without getting overwhelmed.
#
# **First, let’s acknowledge your strengths:** You're already saving a phenomenal amount! The key now is to look for small, targeted improvements.
#
# **Looking at your spending, it's clear that Food ($122.75) is your largest expense.** That's perfectly normal – food is a necessity! But, as with any area, there's always room to optimize. Here are a few ideas, keeping in mind this is general advice, and what works for one person might not for another:
#
# *   **Meal Planning & Prep:** This is a big one. When you plan your meals for the week and cook at home, you’re significantly less likely to spend money on takeout or eating out. Even prepping some lunches and snacks in advance can make a huge difference.
# *   **Grocery Shopping Strategies:** Look for sales, use coupons, consider store brands (often just as good!), and buy in bulk for items you use frequently. Don’t shop when you're hungry – you'll make impulse buys!
# *   **Track Your Spending More Closely:** You’ve got a good overview, but sometimes a more detailed breakdown (using a budgeting app or even just a simple notebook) can reveal sneaky expenses like coffee runs or extra snacks.
#
# **Your Transportation expense of $45.00 is relatively low.** That’s great! If it’s primarily related to commuting, consider if there are ways to reduce that – perhaps carpooling, biking, or public transport (if feasible) could save you some money.
#
# **Now, about saving *more*...** Since you’re already saving 94.4%, let's think about where that money could go. Here are some options:
#
# *   **Increase your Savings Rate (slightly):**  You're already at 94.4%!  It’s possible to nudge that up a little bit – even an extra 1-2% can add up over time.  Consider setting a specific savings goal (like a vacation or a down payment) to motivate you.
# *   **Explore Investment Options:** With such a high savings rate, now's a great time to start learning about investing. Even small amounts invested consistently over time can grow significantly due to the power of compounding. However, please remember, investing involves risk – research different options and understand your risk tolerance. (I can provide some general resources on this if you’d like.)
# *   **Set Specific Savings Goals:** Knowing *why* you're saving can be incredibly motivating.
#
# **Important Disclaimer:** *I want to reiterate that this is purely educational advice based on the information you've provided. It’s not a substitute for professional financial advice. A qualified financial advisor can help you create a personalized plan based on your specific circumstances, goals, and risk tolerance.*
#
# **To help me give you even more targeted suggestions, could you tell me a little more about:**
#
# *   What do you primarily spend your money on besides food and transportation?
# *   What are your long-term financial goals (e.g., retirement, buying a home, travel)?

# %% [markdown]
# ## Step 6: Create Interactive Chat Function
#
# Let's make it easy to chat with our financial sage.  This function creates a simple “chat” with a friendly money expert. When you run it, you can type questions about your finances, ask it to analyse your spending, or type quit to stop. If you ask for an analysis, it reads your transaction file, shows a summary of where your money goes, and can give extra tips if you ask follow-up questions. For anything else, it just gives general financial advice—like a basic chatbot focused on money matters.

# %%
def chat_with_sage():
    """Interactive chat with the financial sage"""

    print("💰 Welcome to the Financial Sage! 💰")
    print("Ask me any financial question, or type 'analyse' to look at your transactions.")
    print("Type 'quit' to exit.\n")

    while True:
        user_input = input("You: ")

        if user_input.lower() == 'quit':
            print("Sage: May your finances prosper! Goodbye!")
            break
        elif user_input.lower() == 'analyse':
            # Analyze transaction data
            analysis = analyse_transactions('transactions.csv')
            print(f"Sage: Here's your financial analysis:\n{analysis}")

            follow_up = input("\nAny questions about your spending? ")
            if follow_up.strip():
                advice = get_data_advice('transactions.csv', follow_up)
                print(f"Sage: {advice}")
        else:
            # Regular financial advice
            advice = get_advice('transactions.csv', user_input)
            print(f"Sage: {advice}")

        print()  # Add spacing

# %% [markdown]
# **Lets start the chatbot**
#
# > The chat_with_sage() function starts an interactive text-based conversation with a “Financial Sage” assistant. It greets the user and then repeatedly waits for input until the user types quit, which ends the chat. If the user types analyse, it calls a helper function analyse_transactions('transactions.csv') to summarise spending data from a CSV file and displays the results. After that, it offers a follow-up question prompt; if the user enters something, it calls get_data_advice('transactions.csv', follow_up) to give personalised insights based on the transaction data. For any other message, it assumes a normal financial question and calls get_advice(user_input) to generate general advice. After each response it prints a blank line for neat spacing, effectively creating a simple loop that handles quitting, transaction analysis, and everyday finance queries.

# %%
chat_with_sage()

# %% [markdown]
# ## Step 7: Test with Different Questions
#
# Let's test our sage with various financial questions:

# %%
# Test different types of questions
test_questions = [
    "I'm 22 and just started working. How should I begin investing?",
    "What's the difference between stocks and bonds?",
    "How much should I have in an emergency fund?",
    "Is it better to pay off debt or invest?",
    "Based on my spending, should I be worried about anything?"
]

print("Testing Financial Sage with various questions:")
print("=" * 50)

for question in test_questions:
    print(f"\nQuestion: {question}")

    if "based on my spending" in question.lower():
        # Use transaction data for this question
        answer = get_advice('transactions.csv', question)
    else:
        # Regular advice
        answer = financial_sage(question)

    print(f"Sage: {answer[:200]}...")  # Show first 200 characters
    print("-" * 30)
# Out:
# Testing Financial Sage with various questions:
# ==================================================
#
# Question: I'm 22 and just started working. How should I begin investing?
# Sage: Okay, fantastic! Starting to think about investing at 22 is *absolutely* one of the smartest things you can do. Seriously, time is your greatest asset when it comes to investing – the longer you inves...
# ------------------------------
#
# Question: What's the difference between stocks and bonds?
# Sage: Hello there! That’s a fantastic question – it’s one that’s absolutely crucial to understanding how investing works. Let’s break down the difference between stocks and bonds. Think of it like this: the...
# ------------------------------
#
# Question: How much should I have in an emergency fund?
# Sage: Hello there! It’s wonderful you’re thinking about building a solid financial foundation. That’s a really smart move, and let's talk about emergency funds – they're absolutely critical.
#
# Now, the ques...
# ------------------------------
#
# Question: Is it better to pay off debt or invest?
# Sage: Hello there! That’s a fantastic question, and one that a *lot* of people wrestle with. It’s a really common dilemma – wanting to clear your slate while also building wealth. The short answer is: it’s ...
# ------------------------------
#
# Question: Based on my spending, should I be worried about anything?
# Sage: Okay, let’s take a look at this fantastic financial picture you’ve presented! Seriously, a 94.4% savings rate is something to be incredibly proud of. That’s a remarkable achievement, and it demonstrat...
# ------------------------------

# %% [markdown]
# ## Step 8: Ask AI for Improvements
#
# Let's ask AI how to make our chatbot better.  Try this prompt:
#
# ```
# I built a simple financial advisor chatbot that:
# - Answers financial questions with educational advice
# - Analyzes CSV transaction data
# - Combines data analysis with personalized advice
#
# How could I improve this chatbot? What features would make it more useful?
# What are potential issues I should watch out for?
# ```

# %% [markdown]
# ## Your Turn: Extend the Chatbot
#
# Try adding one of these features with AI help:
#
# * Add budget planning capabilities
# * Include goal-setting and tracking
# * Add investment portfolio analysis
# * Create spending categorization rules
# * Add financial education tips

# %%
# Implement your chosen extension here
def my_chatbot_extension():
    """Custom extension to the financial sage with user goals"""

    question = "How can I save more money each month?"
    user_goal = "I want to save for an emergency fund"

    personality = """
    You are a wise Financial Sage with years of experience in personal finance.
    You give educational, general advice about money management, investing, and budgeting.
    You speak in a friendly but knowledgeable tone.
    Always remind users that this is educational content, not professional financial advice.
    """

    full_prompt = f"""
    {personality}

    User financial goal: {user_goal}
    User question: {question}

    Give clear, simple, educational financial advice based on the user's goal.
    """

    response = call_ollama(full_prompt)
    print("Extended Financial Sage says:")
    print(response)

# Test your extension
my_chatbot_extension()
# Out:
# Extended Financial Sage says:
# Okay, that’s a fantastic goal – building an emergency fund is one of the smartest and most important things you can do for your financial wellbeing! It’s so good you’re already thinking about how to boost your savings.
#
# Let's talk about how you can save more money each month to reach that emergency fund goal. It's often about small changes that, over time, really add up. Here's a breakdown of some ideas, keeping in mind this is general advice – the best approach will depend on your individual situation:
#
# **1. Track Your Spending – You Can’t Fix What You Don’t Know!**
#
# *   **Start Simple:** For just one month, really pay attention to where your money is going.  There are lots of free apps like Mint, YNAB (You Need a Budget), or even just a simple spreadsheet. Just jot down *everything* you spend.
# *   **Categorize:** Group your spending – groceries, entertainment, transportation, eating out, etc. This helps you see where you’re overspending.
#
# **2. Identify "Easy Wins" – Small Cuts, Big Impact**
#
# *   **Coffee/Drinks:**  Brewing your own coffee or tea at home can save a surprising amount each month.
# *   **Eating Out:**  Packing your lunch a few times a week is a huge saver. Even reducing eating out to once a week can make a difference.
# *   **Subscriptions:**  Do you *really* use all those streaming services or gym memberships?  Look for subscriptions you can cancel or downgrade.
# *   **Impulse Purchases:**  This is a big one! Before making a non-essential purchase, ask yourself, "Do I *need* this, or just *want* it?"  A 24-hour rule can help – wait a day before buying something you weren’t planning on.
#
# **3. Create a Realistic Budget – Plan Your Money, Don’t Let It Control You**
#
# *   **The 50/30/20 Rule:** This is a good starting point: 50% of your income goes to needs (rent, utilities, groceries), 30% to wants (entertainment, dining out), and 20% to savings and debt repayment.  Adjust these percentages to fit your priorities.
# *   **Set Savings Goals:**  Specifically, decide how much you want to save each month for your emergency fund. Even $50 or $100 a month is a great start!
#
# **4. Automate Your Savings – Make it Effortless**
#
# *   **Pay Yourself First:**  Set up an automatic transfer from your checking account to a savings account on payday.  Treat it like a bill you *have* to pay.
#
# **5. Small Changes Add Up – Don't Get Discouraged**
#
# *   **Round Up:** Some banks will automatically round up your purchases to the nearest dollar and transfer the difference to your savings.
# *   **Cashback Rewards:**  Use cashback credit cards strategically (but *pay them off in full each month* to avoid interest charges!).
#
#
#
# **Important Reminder:**  This is all about building good habits. Don’t try to change everything at once. Start with one or two small changes and build from there. Consistency is key!
#
# **Disclaimer:** *I’m an AI and cannot provide financial advice. This information is for educational purposes only. It’s always best to consult with a qualified financial advisor who can assess your specific situation and provide personalized recommendations.*
#
# To help me give you even more tailored advice, could you tell me a little bit about:
#
# *   Roughly what your income looks like each month?
# *   Where you think you might be overspending the most?

# %% [markdown]
# ## Key Takeaways
#
# You've built a financial advisor chatbot that:
# - Uses AI to provide educational financial advice
# - Analyzes real transaction data from CSV files
# - Combines data insights with personalized recommendations
# - Demonstrates how to use LLMs for domain-specific applications
#
# This shows how AI can be used to create helpful financial tools while maintaining appropriate disclaimers about not providing professional financial advice.
#
# ## Next Steps
#
# - Upload your own transactions.csv file and test the analysis
# - Add more sophisticated financial calculations
# - Integrate with the API and scraping tutorials
# - Build a Gradio interface for better user experience
# - Explore more advanced financial analysis features
#
# Remember: This is educational content and not professional financial advice!
